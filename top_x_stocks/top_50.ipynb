# %%
import pandas as pd
# import matplotlib.pyplot as plt
import numpy as np
import os
import yaml

# %%
top_50 = pd.read_csv('./top_50_updated.csv')
top_50.to_pickle('./top_50.pkl')

# %%
top_50_dict = {value: { 'symbol': value } for value in top_50['stock']}

with open('../sample.yaml', 'r') as yaml_file:
    new_yaml = yaml.load(yaml_file, Loader=yaml.SafeLoader)
    new_yaml.update(top_50_dict)
    
with open('../sample.yaml', 'w') as yaml_file:
    yaml.safe_dump(new_yaml, yaml_file, sort_keys=False)

# %%
parameters = pd.read_pickle('top_50.pkl')
# parameters.set_index("stock", inplace=True)
parameters
# Out:
#         stock  buy_threshold  sell_threshold  lookback_period
# 0    CHOLAFIN            0.6            -0.8              8.0
# 1   INDUSINDB            0.3            -0.7             10.0
# 2   HINDPETRO            0.2            -0.3              5.0
# 3    JUBLFOOD            0.6            -0.6              6.0
# 4    ASHOKLEY            0.6            -0.2              5.0
# 5    JSWSTEEL            0.2            -0.7              7.0
# 6         BEL            0.2            -0.3             12.0
# 7   METROPOLI            0.7            -0.2             14.0
# 8        GNFC            0.2            -0.8             14.0
# 9   IBULHSGFI            0.2            -0.7              6.0
# 10  GUJGASLTD            0.8            -0.6              9.0
# 11       GAIL            0.3            -0.2              5.0
# 12  CANFINHOM            0.4            -0.6             12.0
# 13  BHARATFOR            0.4            -0.8              7.0
# 14  KOTAKBANK            0.6            -0.6             10.0
# 15         MM            0.8            -0.6             13.0
# 16  ICICIBANK            0.6            -0.5             10.0
# 17  ICICIPRUL            0.2            -0.8              5.0
# 18     BIOCON            0.3            -0.5              9.0
# 19      MMFIN            0.6            -0.2             14.0
# 20  BANDHANBN            0.3            -0.2              9.0
# 21  APOLLOTYR            0.2            -0.4              5.0
# 22    IPCALAB            0.6            -0.5             14.0
# 23   AXISBANK            0.3            -0.3             13.0
# 24    HAVELLS            0.7            -0.8             13.0
# 25  COALINDIA            0.2            -0.7              8.0
# 26  MANAPPURA            0.2            -0.7              5.0
# 27        PEL            0.7            -0.6             14.0
# 28  ASIANPAIN            0.2            -0.8             13.0
# 29        PVR            0.2            -0.8             13.0
# 30      CIPLA            0.6            -0.7              9.0
# 31  INDUSTOWE            0.4            -0.2             11.0
# 32        FSL            0.8            -0.2              5.0
# 33  BERGEPAIN            0.2            -0.7             10.0
# 34        MGL            0.6            -0.7             12.0
# 35   GLENMARK            0.3            -0.3              5.0
# 36   INDHOTEL            0.6            -0.5              5.0
# 37        IGL            0.5            -0.2             13.0
# 38  BALRAMCHI            0.8            -0.7              9.0
# 39  ADANIPORT            0.4            -0.4             13.0
# 40   HDFCLIFE            0.4            -0.5              9.0
# 41        DLF            0.3            -0.6              7.0
# 42  COROMANDE            0.8            -0.6              9.0
# 43      DABUR            0.4            -0.7              6.0
# 44  AUROPHARM            0.2            -0.3             13.0
# 45        HAL            0.3            -0.8             13.0
# 46  MCDOWELL-            0.8            -0.2             14.0
# 47       BPCL            0.2            -0.3              6.0
# 48     AUBANK            0.2            -0.8              5.0
# 49  LAURUSLAB            0.3            -0.3             14.0

# %%
config = parameters.to_dict(orient='index')

# %%
config[0]
# Out:
# {'stock': 'CHOLAFIN',
#  'buy_threshold': 0.6,
#  'sell_threshold': -0.8,
#  'lookback_period': 8.0}
